# %% [markdown]
# # Real Estate Clean up
#
# This is a real dataset, and it was downloaded using web scraping techniques. The data contains registers from **Fotocasa** which is one of the most popular real estate websites in Spain. Please, do not do this (web scraping) unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and in no case were economic returns obtained from it.
#
# It contains thousands of data from real houses published on the web www.fotocasa.com. Your goal is to extract as much information as possible with the knowledge you have so far about data science, for example what is the most expensive house in the entire dataset?
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Exercise 00. Read the dataset assets/real_estate.csv and try to visualize the table (★☆☆)

# %%
import pandas as pd

# This CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Exercise 01. Which is the most expensive house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
max_value = ds.loc[ds['price'].idxmax()]
print('The house with address',max_value.address,'is most expensive and its price is',max_value.price,'USD')
# Out:
# The house with address El Escorial is most expensive and its price is 8500000 USD

# %% [markdown]
# #### Exercise 02. Which is the cheapest house in the dataset? (★☆☆)
#
# Print the address and the price of the selected house. For example:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
min_value = ds.loc[ds['price'].idxmin()]
print('The house with address',min_value.address,'is cheapest and its price is',min_value.price,'USD')
# Out:
# The house with address Parla is cheapest and its price is 0 USD

# %% [markdown]
# #### Exercise 03. Which is the biggest and the smallest house in the dataset? (★☆☆)
#
# Print both the address and the surface of the selected houses. For example:
#
# `The biggest house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smallest house is located on County Road 1 N and its surface is 200 meters`

# %%
big_value = ds.loc[ds['surface'].idxmax()]
small_value = ds.loc[ds['surface'].idxmin()]
print('The biggest house is located on',big_value.address,'and its surface is',big_value.surface,'meters')
print('The smallest house is located on',small_value.address,'and its surface is',small_value.surface,'meters')
# Out:
# The biggest house is located on Sevilla la Nueva and its surface is 249000.0 meters
# The smallest house is located on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Exercise 04. How many populations (level5 column) the dataset contains? (★☆☆)
#
# Print the names of the populations with a comma as a separator. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
populations = ds['level5']
pop_count = populations.count()
print('There are',pop_count,'populations.')
for x in populations:
    print(x,',')
# Out:
# There are 15335 populations.
# Arganda del Rey ,
# Fuenlabrada ,
# Boadilla del Monte ,
# Fuenlabrada ,
# Arganda del Rey ,
# Las Rozas de Madrid ,
# Las Rozas de Madrid ,
# Las Rozas de Madrid ,
# Las Rozas de Madrid ,
#  Madrid Capital ,
#  Madrid Capital ,
# Villaviciosa de Odón ,
# Pinto ,
# Valdemoro ,
# Navalcarnero ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
# Pozuelo de Alarcón ,
# Torrejón de Ardoz ,
# Navalagamella ,
# San Sebastián de los Reyes ,
#  Madrid Capital ,
# Rivas-vaciamadrid ,
# Alpedrete ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
# Móstoles ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
# San Fernando de Henares ,
# Coslada ,
#  Madrid Capital ,
# Becerril de la Sierra ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
#  Madrid Capital ,
# Alcalá de Henares ,
#  Madrid Capital ,
#  Madrid Capital ,
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain NAs? (★☆☆)
#
# Print a boolean value (`True` or `False`) followed by the rows/cols that contains NAs.

# %%
na_data = ds[ds.columns[ds.isnull().any()]].isnull().sum()
print(na_data.any())
print(na_data)
# Out:
# True
# realEstate_name        10
# phone_realEstate      794
# rooms                 353
# bathrooms             345
# surface              1250
# description           142
# level4               6643
# level6              14627
# level7               2277
# level8               8579
# zipCode             15335
# customZone          15335
# dtype: int64

# %% [markdown]
# #### Exercise 06. Delete the NAs of the dataset, if applicable (★★☆)
#
# Print a comparison between the dimensions of the original DataFrame versus the DataFrame after the deletions.

# %%
ds2 = ds.dropna(how = 'all')
print(ds.size, ds2.size)
# Out:
# 582730 582730

# %% [markdown]
# #### Exercise 07. Which is the mean of prices in the population (level5 column) of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the obtained value.

# %%
arroyo_ds = ds.query("level5 == 'Arroyomolinos (Madrid)'")
ds_mean = arroyo_ds['price'].mean()
print(ds_mean,'is the mean price of Arroyomolinos (Madrid)')
# Out:
# 294541.59854014596 is the mean price of Arroyomolinos (Madrid)

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population (level5 column) of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
import matplotlib.pyplot as plt
arroyo_ds['price'].hist()
plt.xlabel('house price')
plt.ylabel('number of houses')
plt.show()

# %% [markdown]
# The majority of houses fall between 200000 and 400000.

# %% [markdown]
# #### Exercise 09. Are the average prices of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about them.

# %%
valdemorillo_ds = ds[ds['level5'].isin([value for value in ds['level5'] if value == 'Valdemorillo'])]
valdemorillo_mean = valdemorillo_ds['price'].mean()
galapagar_ds = ds[ds['level5'].isin([value for value in ds['level5'] if value == 'Galapagar'])]
galapagar_mean = galapagar_ds['price'].mean()
print('Valdemorillo mean price of',valdemorillo_mean,'is slightly higher than Galapager mean price of',galapagar_mean)
# Out:
# Valdemorillo mean price of 363860.2931034483 is slightly higher than Galapager mean price of 360063.20238095237

# %% [markdown]
# #### Exercise 10. Are the average prices per square meter (price/m2) of "Valdemorillo" and "Galapagar" the same? (★★☆)
#
# Print both average prices and then write a conclusion about it.
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
ds['pps'] = ds['price'] / ds['surface']
valdemorillo_pps = valdemorillo_ds['pps'].mean()
galapagar_pps = galapagar_ds['pps'].mean()
print('Valdemorillo has a lower pps of',valdemorillo_pps,', while Galapagar has a higher pps of',galapagar_pps)
# Out:
# Valdemorillo has a lower pps of 1317.9502109024986 , while Galapagar has a higher pps of 1606.3240303094024

# %% [markdown]
# #### Exercise 11. Analyze the relation between the surface and the price of the houses (★★☆)
#
# Hint: You can make a `scatter plot`, then write a conclusion about it.

# %%
val_gal_ds = [valdemorillo_ds, galapagar_ds]
for loc in val_gal_ds:
    town_ds = val_gal_ds[val_gal_ds['level5'] == loc]
    x = town_ds.price
    y = town_ds.surface
    plt.scatter(x,y)
    plt.xlabel('price')
    plt.ylabel('surface')
    plt.title(loc)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 val_gal_ds = [valdemorillo_ds, galapagar_ds]
#       2 for loc in val_gal_ds:
#       3     town_ds = val_gal_ds[val_gal_ds['level5'] == loc]
#
# NameError: name 'valdemorillo_ds' is not defined

# %% [markdown]
# The majority of houses for Valdemorillo and Galapagar cost below 500000. However, Valdemorillo has larger houses at a lower price, while Galapagar's majority of houses are smaller, under 1000m, and at a wide variety of prices.

# %% [markdown]
# #### Exercise 12. How many real estate agencies does the dataset contain? (★★☆)
#
# Print the obtained value.

# %%
real_estate = ds['id_realEstates']
real_estate_count = list(set(real_estate))
print('There are',len(real_estate_count),'real estate agencies')
# Out:
# There are 14217 real estate agencies

# %% [markdown]
# #### Exercise 13. Which is the population (level5 column) that contains the most houses? (★★☆)
#
# Print both the population and the number of houses.

# %%
population = ds['level5']
house_count = population.value_counts()
print(house_count)
# Out:
# level5
#  Madrid Capital         6643
# Alcalá de Henares        525
# Las Rozas de Madrid      383
# Móstoles                 325
# Getafe                   290
#                         ...
# Fresno de Torote           1
# Pinilla del Valle          1
# Rascafría                  1
# La Hiruela                 1
# Montejo de la Sierra       1
# Name: count, Length: 168, dtype: int64

# %% [markdown]
# #### Exercise 14. Now let's work with the "south belt" of Madrid. Make a subset of the original DataFrame that contains the following populations (level5 column): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Hint: Filter the original DataFrame using the column `level5` and the function `isin`.

# %%
locations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
new_ds = ds[ds['level5'].isin(locations)]
new_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 907 entries, 1 to 15325
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        907 non-null    int64
#  1   id_realEstates    907 non-null    int64
#  2   isNew             907 non-null    bool
#  3   realEstate_name   907 non-null    object
#  4   phone_realEstate  854 non-null    float64
#  5   url_inmueble      907 non-null    object
#  6   rooms             902 non-null    float64
#  7   bathrooms         897 non-null    float64
#  8   surface           787 non-null    float64
#  9   price             907 non-null    int64
#  10  date              907 non-null    object
#  11  description       902 non-null    object
#  12  address           907 non-null    object
#  13  country           907 non-null    object
#  14  level1            907 non-null    object
#  15  level2            907 non-null    object
# ...

# %% [markdown]
# #### Exercise 15. Make a bar plot of the median of the prices and explain what you observe (you must use the subset obtained in Exercise 14) (★★★)
#
# Print the bar of the median of the prices and write in the Markdown cell a brief analysis about the plot.

# %%
median_prices = new_ds.groupby('level5')['price'].median().reset_index()
plt.bar(median_prices['level5'],median_prices['price'])
plt.xlabel('Location')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Getafe has the highest median price at over 250000. Fuenlabrada has the lowest median price at 150000. Alcorcón and Leganés have a similar median price between 150000 and 200000.

# %% [markdown]
# #### Exercise 16. Calculate the sample mean and variance of the variables: price, rooms, surface area and bathrooms (you must use the subset obtained in Exercise 14) (★★★)
#
# Print both values for each variable.

# %%
data = ['price', 'rooms', 'surface', 'bathrooms']
for d in data:
    new_ds_mean = new_ds[d].mean()
    new_ds_var = new_ds[d].var()
    print(d,'mean:',new_ds_mean,'variance:',new_ds_var)
# Out:
# price mean: 223094.48070562293 variance: 14921367508.04902
# rooms mean: 3.0177383592017737 variance: 0.7188858892927542
# surface mean: 111.75222363405337 variance: 4263.051760316337
# bathrooms mean: 1.633221850613155 variance: 0.5717968625577321

# %% [markdown]
# #### Exercise 17. What is the most expensive house in each population? You must use the subset obtained in Exercise 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population.

# %%
for loc in locations:
    max_price = new_ds[new_ds['level5'] == loc]['price'].max()
    print('The most expensive house in',loc,'costs',max_price)
# Out:
# The most expensive house in Fuenlabrada costs 490000
# The most expensive house in Leganés costs 650000
# The most expensive house in Getafe costs 1050000
# The most expensive house in Alcorcón costs 950000

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in Exercise 14) (★★★)
#
# For the normalization method, you can use the one you consider; there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot.
#
# Hint: You can help yourself by reviewing the *multihist* demo of Matplotlib.

# %%
normalized_ds = []
for loc in locations:
    location_data = new_ds[new_ds['level5'] == loc]
    prices = location_data['price']
    min_price = prices.min()
    max_price = prices.max()
    normalized_prices = (prices - min_price) / (max_price - min_price)
    normalized_loc_ds = pd.DataFrame({
        "Location": [loc] * len(normalized_prices),
        "Normalized_Price": normalized_prices
    })
    normalized_ds.append(normalized_loc_ds)

fig, axes = plt.subplots(2, 2, sharey = True)
for i, loc in enumerate(locations):
    axes[i// 2, i % 2].hist(normalized_ds[i]["Normalized_Price"])
    axes[i // 2, i % 2].set_title(loc)
    axes[i // 2, i % 2].set_xlabel("Normalized Price")
    axes[i // 2, i % 2].set_ylabel("Frequency")
    plt.tight_layout()
    
plt.show()

# %% [markdown]
# Getafe has the highest normalized price, between 150000 and 400000. Alcorcón has the lowest normalized price, under 150000. Fuenlabrada and Leganés have a similar normalized price, under 200000.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square meter) and then analyze the values.

# %%
locs = ['Getafe', 'Alcorcón']
for loc in locs:
    town_ds = new_ds[new_ds['level5'] == loc]
    mean_price = town_ds['price'].mean()
    mean_surface = town_ds['surface'].mean()
    mean_pps = mean_price / mean_surface
    print(loc,'mean price per square meter is',mean_pps)

print('Getafe has a more affordable price per square meter')
# Out:
# Getafe mean price per square meter is 2088.6390850827283
# Alcorcón mean price per square meter is 2172.2584787023497
# Getafe has a more affordable price per square meter

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph. You must use the subset obtained in Exercise 14 (★★☆)
#
# Hint: Make a scatter plot of each population using subplots.

# %%
for loc in locations:
    location_data = new_ds[new_ds['level5'] == loc]
    x = location_data.price
    y = location_data.surface
    fig, ax = plt.subplots()
    ax.scatter(x, y)
    plt.xlabel('price')
    plt.ylabel('surface')
    plt.title(loc)

plt.show()

# %% [markdown]
# #### Exercise 21. Make a plot of the coordinates (latitude and longitude columns) of the south belt of Madrid by color of each population (you must use the subset obtained in Exercise 14) (★★★★)
#
# Execute the following cell, and then start coding in the next one. You must implement a simple code that transforms the coordinates columns in a Python dictionary (add more information if needed) and then add it to the map

# %%
from ipyleaflet import Map, basemaps

# Map centered on (60 degrees latitude and -2.2 degrees longitude)
# Latitude, longitude
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map

# %%
## HERE: plot the coordinates of the estates

## PUT HERE YOUR CODE:
